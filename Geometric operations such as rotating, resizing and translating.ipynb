# %% [markdown]
# <a href="https://colab.research.google.com/github/ZaulTyt/AI-and-Image-Processing---CAP-631/blob/main/Geometric%20operations%20such%20as%20rotating%2C%20resizing%20and%20translating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
MY_IMAGE = "/content/Mount-Everest.webp"

# %%
img = cv2.imread(MY_IMAGE)
height, width = img.shape[:2]
window_name = "2D Transformations"

# %%
# Display the original and transformed images
plt.figure(figsize=(15, 10))

plt.subplot(2, 2, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1599.5), np.float64(1111.5), np.float64(-0.5))

# %%
# 1. Translate the image
translation_matrix = np.float32([[1, 0, 50], [0, 1, 30]]) # translate by 50px horizontally, 30px vertically
img_translated = cv2.warpAffine(img, translation_matrix, (width, height))

plt.subplot(2, 2, 2)
plt.imshow(cv2.cvtColor(img_translated, cv2.COLOR_BGR2RGB))
plt.title('Translated Image')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1599.5), np.float64(1111.5), np.float64(-0.5))

# %%
# 2. Resize the image to 50% of its original size
img_resized = cv2.resize(img, (int(width * 0.5), int(height * 0.5)))

plt.subplot(2, 2, 3)
plt.imshow(cv2.cvtColor(img_resized, cv2.COLOR_BGR2RGB))
plt.title('Resized Image')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(799.5), np.float64(555.5), np.float64(-0.5))

# %%
# 3. Rotate the image by 60 degrees about its center
center = (width // 2, height // 2)
rotation_matrix = cv2.getRotationMatrix2D(center, 60, 1.0) # 60 degrees, scale = 1.0
img_rotated = cv2.warpAffine(img, rotation_matrix, (width, height))

plt.subplot(2, 2, 4)
plt.imshow(cv2.cvtColor(img_rotated, cv2.COLOR_BGR2RGB))
plt.title('Rotated Image')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
horizontal_flip = cv2.flip(img, 1)
vertical_flip = cv2.flip(img, 0)

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Original Image")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(cv2.cvtColor(horizontal_flip, cv2.COLOR_BGR2RGB))
plt.title("Horizontal Flip")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(cv2.cvtColor(vertical_flip, cv2.COLOR_BGR2RGB))
plt.title("Vertical Flip")
plt.axis('off')

plt.tight_layout()
plt.show()
